# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Markdown as md
from copy import deepcopy
import scipy
from scipy import signal
import seaborn as sns
plt.rcParams['figure.figsize'] = [18, 5]

# %%
df = pd.read_csv('./2019 03 18 12H 56M Electropherogram.csv')
df.set_index('Size (nt)', inplace=True)
display(df.head())
df.loc[1:100, df.columns != "H12"].plot(legend = False)
df.loc[5:20, df.columns != "H12"].plot(legend = False)
df.loc[50:100, df.columns != "H12"].plot(legend = False)
# Out:
#            A1: 2N:30s  A2: 2N:45s  A3: 2N:1min  A4: 2N:2min  A5: 2N:3min  \
# Size (nt)
# 0.30           198.50      279.69       267.72       254.48       334.85
# 0.47           321.74      422.15       409.70       403.99       502.07
# 0.65           433.76      526.32       518.91       532.03       620.95
# 0.82           485.62      541.74       543.05       580.40       633.11
# 1.00           452.00      460.13       469.51       524.50       531.68
#
#            A6: 2N:5min  A7: 2N:7min  A8: 2N:10min  A9: 2N:15min  \
# Size (nt)
# 0.30            280.15       243.79        217.11        287.62
# 0.47            436.01       393.42        366.88        442.12
# 0.65            563.89       529.85        515.39        562.51
# 0.82            604.30       593.03        599.64        590.75
# 1.00            536.12       551.08        577.30        511.13
#
#            A10: 2N:20min      ...       H3: 40N:1min  H4: 40N:2min  \
# Size (nt)                     ...
# 0.30              227.10      ...             401.16        371.66
# 0.47              378.52      ...             598.85        545.44
# 0.65              527.82      ...             738.84        662.20
# 0.82              611.99      ...             751.78        663.66
# 1.00              589.03      ...             629.60        547.95
#
#            H5: 40N:3min  H6: 40N:5min  H7: 40N:7min  H8: 40N:10min  \
# Size (nt)
# 0.30             399.11        315.79        308.84         460.42
# 0.47             613.61        496.02        496.39         674.77
# 0.65             778.47        644.71        663.43         817.70
# 0.82             813.76        692.38        735.39         818.39
# 1.00             699.92        613.82        675.60         675.35
#
#            H9: 40N:15min  H10: 40N:20min  H11: 40N:30min  H12: SampH12
# Size (nt)
# 0.30              308.91          315.62          371.46       1250.33
# 0.47              484.98          509.68          566.47       2032.70
# 0.65              632.93          685.93          710.22       2713.89
# 0.82              685.00          766.30          732.18       2983.54
# 1.00              614.50          709.93          619.92       2707.21
#
# [5 rows x 96 columns]

# %%
cols = ["A", "B", "C", "D", "E", "F", "G", "H"]
rows = [str(x) for x in range(1,13)]

newNames = {}
sampleMap = {}
for col in df.columns:
    if ": " in col:
        splt = col.split(": ")
        newNames[col] = splt[0]
        sampleMap[splt[0]] = splt[1]
    else:
        sampleMap[col] = col
df.rename(columns=newNames, inplace=True)
display(df)
# Out:
#                    A1          A2          A3          A4           A5  \
# Size (nt)
# 0.30       661.666667  932.300000  892.400000  848.266667  1116.166667
# 0.47       684.553191  898.191489  871.702128  859.553191  1068.234043
# 0.65       667.323077  809.723077  798.323077  818.507692   955.307692
# 0.82       592.219512  660.658537  662.256098  707.804878   772.085366
# 1.00       452.000000  460.130000  469.510000  524.500000   531.680000
# 2.00       175.075000  160.850000  167.555000  196.025000   183.355000
# 2.16       104.569444   85.208333   91.384259  111.717593    95.671296
# 2.33        52.042918   36.506438   41.386266   51.961373    40.502146
# 2.49        21.590361   12.277108   16.120482   19.417671    13.783133
# 2.66         7.000000    2.680451    5.872180    5.357143     3.424812
# 2.82         1.056738   -0.294326    2.414894    0.687943     0.088652
# 2.99        -1.170569   -0.983278    1.197324   -0.438127    -0.953177
# 3.15        -1.920635   -1.079365    0.568254   -0.530159    -1.333333
# 3.32        -1.975904   -1.096386    0.114458   -0.361446    -1.463855
# 3.48        -1.617816   -1.137931   -0.212644   -0.097701    -1.482759
# 3.65        -1.032877   -1.142466   -0.419178    0.191781    -1.452055
# 3.81        -0.438320   -1.031496   -0.511811    0.435696    -1.417323
# 3.97         0.015113   -0.773300   -0.521411    0.586902    -1.342569
# 4.14         0.268116   -0.422705   -0.487923    0.637681    -1.159420
# 4.30         0.341860   -0.086047   -0.425581    0.595349    -0.844186
# 4.47         0.174497    0.138702   -0.317673    0.541387    -0.447427
# 4.63         0.019438    0.133909   -0.151188    0.509719    -0.095032
# 4.80        -0.093750    0.000000    0.045833    0.504167     0.102083
# 4.96        -0.110887   -0.086694    0.217742    0.522177     0.112903
# 5.13        -0.013645   -0.064327    0.319688    0.553606    -0.153996
# 5.29         0.156900    0.069943    0.340265    0.584121    -0.238185
# 5.46         0.320513    0.254579    0.294872    0.591575    -0.208791
# 5.62         0.403915    0.421708    0.176157    0.556940    -0.080071
# 5.78         0.385813    0.520761    0.190311    0.484429     0.089965
# 5.95         0.300840    0.551261    0.299160    0.410084     0.211765
# ...               ...         ...         ...         ...          ...
# 345.40       0.000000    0.000000   -0.041199    0.000000     0.000000
# 346.30       0.000000    0.000000    0.000000    0.000000     0.000000
# 347.19       0.000000    0.000000    0.000000    0.000000     0.000000
# 348.09       0.000000    0.000000    0.000000    0.000000     0.000000
# 348.99       0.000000    0.000000    0.000000    0.000000     0.000000
# 349.89       0.000000    0.000000    0.000000    0.000000     0.000000
# 350.78       0.000000    0.000000    0.000000    0.000000     0.000000
# 351.68       0.000000    0.000000    0.000000    0.000000     0.000000
# 352.58       0.000000    0.000000    0.000000    0.000000     0.000000
# 353.48       0.000000    0.000000    0.000000    0.000000     0.000000
# 354.37       0.000000    0.000000    0.000000    0.000000     0.000000
# 355.27       0.000000    0.000000    0.000000    0.000000     0.000000
# 356.17       0.000000    0.000000    0.000000    0.000000     0.000000
# 357.07       0.000000    0.000000    0.000000    0.000000     0.000000
# 357.97       0.000000    0.000000    0.000000    0.000000     0.000000
# 358.86       0.000000    0.000000    0.000000    0.000000     0.000000
# 359.76       0.000000    0.000000    0.000000    0.000000     0.000000
# 360.66       0.000000    0.000000    0.000000    0.000000     0.000000
# 361.56       0.000000    0.000000    0.000000    0.000000     0.000000
# 362.45       0.000000    0.000000    0.000000    0.000000     0.000000
# 363.35       0.000000    0.000000    0.000000    0.000000     0.000000
# 364.25       0.000000    0.000000    0.000000    0.000000     0.000000
# 365.15       0.000000    0.000000    0.000000    0.000000     0.000000
# 366.04       0.000000    0.000000    0.000000    0.000000     0.000000
# 366.94       0.000000    0.000000    0.000000    0.000000     0.000000
# 367.84       0.000000    0.000000    0.000000    0.000000     0.000000
# 368.74       0.000000    0.000000    0.000000    0.000000     0.000000
# 369.63       0.000000    0.000000    0.000000    0.000000     0.000000
# 370.53       0.000000    0.000000    0.000000    0.000000     0.000000
# 371.43       0.000000    0.000000    0.000000    0.000000     0.000000
#
#                    A6          A7          A8          A9         A10  \
# Size (nt)
# 0.30       933.833333  812.633333  723.700000  958.733333  757.000000
# 0.47       927.680851  837.063830  780.595745  940.680851  805.361702
# 0.65       867.523077  815.153846  792.907692  865.400000  812.030769
# 0.82       736.951220  723.207317  731.268293  720.426829  746.329268
# 1.00       536.120000  551.080000  577.300000  511.130000  589.030000
# 2.00       196.525000  212.295000  229.475000  181.350000  234.895000
# 2.16       109.851852  125.175926  138.745370   96.708333  143.236111
# 2.33        50.309013   60.703863   68.206009   40.862661   71.742489
# 2.49        18.795181   24.084337   26.787149   12.726908   29.373494
# 2.66         5.447368    7.443609    7.669173    1.714286    9.402256
# 2.82         0.932624    1.489362    0.900709   -1.464539    2.010638
# 2.99        -0.327759   -0.117057   -0.903010   -2.026756   -0.147157
# 3.15        -0.609524   -0.298413   -1.231746   -1.987302   -0.600000
# 3.32        -0.611446   -0.129518   -1.240964   -1.870482   -0.614458
# 3.48        -0.500000    0.034483   -1.201149   -1.787356   -0.531609
# 3.65        -0.317808    0.093151   -1.120548   -1.753425   -0.438356
# 3.81        -0.076115    0.039370   -1.005249   -1.782152   -0.372703
# 3.97         0.201511   -0.103275   -0.874055   -1.836272   -0.360202
# 4.14         0.473430   -0.299517   -0.770531   -1.869565   -0.403382
# 4.30         0.679070   -0.497674   -0.732558   -1.855814   -0.483721
# 4.47         0.765101   -0.651007   -0.756152   -1.769575   -0.574944
# 4.63         0.740821   -0.745140   -0.812095   -1.622030   -0.660907
# 4.80         0.668750   -0.770833   -0.866667   -1.420833   -0.733333
# 4.96         0.618952   -0.741935   -0.895161   -1.191532   -0.780242
# 5.13         0.606238   -0.672515   -0.873294   -0.959064   -0.777778
# 5.29         0.599244   -0.597353   -0.786389   -0.765595   -0.708885
# 5.46         0.562271   -0.536630   -0.642857   -0.642857   -0.571429
# 5.62         0.487544   -0.489324   -0.483986   -0.640569   -0.389680
# 5.78         0.391003   -0.425606   -0.269896   -0.666090   -0.211073
# 5.95         0.289076   -0.331092   -0.198319   -0.657143   -0.105882
# ...               ...         ...         ...         ...         ...
# 345.40      -0.035466   -0.049566   -0.041633   -0.041054   -0.042907
# 346.30      -0.034681   -0.052556   -0.040456    0.000000   -0.042449
# 347.19      -0.033526   -0.054351    0.000000    0.000000   -0.042455
# 348.09      -0.032607   -0.051912    0.000000    0.000000   -0.043092
# 348.99       0.000000   -0.049056    0.000000    0.000000   -0.044901
# 349.89       0.000000   -0.047443    0.000000    0.000000   -0.048272
# 350.78       0.000000   -0.047580    0.000000    0.000000   -0.052683
# 351.68       0.000000    0.000000    0.000000    0.000000    0.000000
# 352.58       0.000000    0.000000    0.000000    0.000000    0.000000
# 353.48       0.000000    0.000000    0.000000    0.000000    0.000000
# 354.37       0.000000    0.000000    0.000000    0.000000    0.000000
# 355.27       0.000000    0.000000    0.000000    0.000000    0.000000
# 356.17       0.000000    0.000000    0.000000    0.000000    0.000000
# 357.07       0.000000    0.000000    0.000000    0.000000    0.000000
# 357.97       0.000000    0.000000    0.000000    0.000000    0.000000
# 358.86       0.000000    0.000000    0.000000    0.000000    0.000000
# 359.76       0.000000    0.000000    0.000000    0.000000    0.000000
# 360.66       0.000000    0.000000    0.000000    0.000000    0.000000
# 361.56       0.000000    0.000000    0.000000    0.000000    0.000000
# 362.45       0.000000    0.000000    0.000000    0.000000    0.000000
# 363.35       0.000000    0.000000    0.000000    0.000000    0.000000
# 364.25       0.000000    0.000000    0.000000    0.000000    0.000000
# 365.15       0.000000    0.000000    0.000000    0.000000    0.000000
# 366.04       0.000000    0.000000    0.000000    0.000000    0.000000
# 366.94       0.000000    0.000000    0.000000    0.000000    0.000000
# 367.84       0.000000    0.000000    0.000000    0.000000    0.000000
# 368.74       0.000000    0.000000    0.000000    0.000000    0.000000
# 369.63       0.000000    0.000000    0.000000    0.000000    0.000000
# 370.53       0.000000    0.000000    0.000000    0.000000    0.000000
# 371.43       0.000000    0.000000    0.000000    0.000000    0.000000
#
#               ...                H3           H4           H5           H6  \
# Size (nt)     ...
# 0.30          ...       1337.200000  1238.866667  1330.366667  1052.633333
# 0.47          ...       1274.148936  1160.510638  1305.553191  1055.361702
# 0.65          ...       1136.676923  1018.769231  1197.646154   991.861538
# 0.82          ...        916.804878   809.341463   992.390244   844.365854
# 1.00          ...        629.600000   547.950000   699.920000   613.820000
# 2.00          ...        216.030000   185.700000   246.725000   223.945000
# 2.16          ...        111.462963    95.245370   130.949074   123.671296
# 2.33          ...         45.824034    39.927039    55.656652    55.072961
# 2.49          ...         14.212851    14.052209    18.325301    19.164659
# 2.66          ...          2.199248     4.458647     3.875940     4.353383
# 2.82          ...         -1.382979     1.482270    -0.375887    -0.368794
# 2.99          ...         -2.220736     0.448161    -1.270903    -1.525084
# 3.15          ...         -2.339683    -0.098413    -1.317460    -1.742857
# 3.32          ...         -2.237952    -0.448795    -1.168675    -1.789157
# 3.48          ...         -2.060345    -0.646552    -0.991379    -1.844828
# 3.65          ...         -1.865753    -0.709589    -0.852055    -1.901370
# 3.81          ...         -1.740157    -0.677165    -0.795276    -1.913386
# 3.97          ...         -1.715365    -0.612091    -0.798489    -1.816121
# 4.14          ...         -1.741546    -0.599034    -0.811594    -1.601449
# 4.30          ...         -1.734884    -0.693023    -0.786047    -1.341860
# 4.47          ...         -1.615213    -0.859060    -0.709172    -1.116331
# 4.63          ...         -1.380130    -1.002160    -0.611231    -0.984881
# 4.80          ...         -1.068750    -1.039583    -0.535417    -0.997917
# 4.96          ...         -0.750000    -0.969758    -0.506048    -1.012097
# 5.13          ...         -0.331384    -0.842105    -0.506823    -0.976608
# 5.29          ...         -0.266541    -0.722117    -0.510397    -0.892250
# 5.46          ...         -0.272894    -0.648352    -0.479853    -0.783883
# 5.62          ...         -0.307829    -0.642349    -0.439502    -0.690391
# 5.78          ...         -0.339100    -0.690311    -0.397924    -0.626298
# 5.95          ...         -0.336134    -0.768067    -0.354622    -0.601681
# ...           ...               ...          ...          ...          ...
# 345.40        ...          0.000000    -0.080081     0.000000     0.000000
# 346.30        ...          0.000000    -0.079526     0.000000     0.000000
# 347.19        ...          0.000000    -0.078602     0.000000     0.000000
# 348.09        ...          0.000000    -0.077624     0.000000     0.000000
# 348.99        ...          0.000000    -0.076936     0.000000     0.000000
# 349.89        ...          0.000000    -0.076881     0.000000     0.000000
# 350.78        ...          0.000000    -0.077798     0.000000     0.000000
# 351.68        ...          0.000000    -0.079675     0.000000     0.000000
# 352.58        ...          0.000000    -0.082081     0.000000     0.000000
# 353.48        ...          0.000000     0.000000     0.000000     0.000000
# 354.37        ...          0.000000     0.000000     0.000000     0.000000
# 355.27        ...          0.000000     0.000000     0.000000     0.000000
# 356.17        ...          0.000000     0.000000     0.000000     0.000000
# 357.07        ...          0.000000     0.000000     0.000000     0.000000
# 357.97        ...          0.000000     0.000000     0.000000     0.000000
# 358.86        ...          0.000000     0.000000     0.000000     0.000000
# 359.76        ...          0.000000     0.000000     0.000000     0.000000
# 360.66        ...          0.000000     0.000000     0.000000     0.000000
# 361.56        ...          0.000000     0.000000     0.000000     0.000000
# 362.45        ...          0.000000     0.000000     0.000000     0.000000
# 363.35        ...          0.000000     0.000000     0.000000     0.000000
# 364.25        ...          0.000000     0.000000     0.000000     0.000000
# 365.15        ...          0.000000     0.000000     0.000000     0.000000
# 366.04        ...          0.000000     0.000000     0.000000     0.000000
# 366.94        ...          0.000000     0.000000     0.000000     0.000000
# 367.84        ...          0.000000     0.000000     0.000000     0.000000
# 368.74        ...          0.000000     0.000000     0.000000     0.000000
# 369.63        ...          0.000000     0.000000     0.000000     0.000000
# 370.53        ...          0.000000     0.000000     0.000000     0.000000
# 371.43        ...          0.000000     0.000000     0.000000     0.000000
#
#                     H7           H8           H9          H10          H11  \
# Size (nt)
# 0.30       1029.466667  1534.733333  1029.700000  1052.066667  1238.200000
# 0.47       1056.148936  1435.680851  1031.872340  1084.425532  1205.255319
# 0.65       1020.661538  1258.000000   973.738462  1055.276923  1092.646154
# 0.82        896.817073   998.036585   835.365854   934.512195   892.902439
# 1.00        675.600000   675.350000   614.500000   709.930000   619.920000
# 2.00        256.730000   228.830000   228.180000   272.245000   214.510000
# 2.16        148.800926   117.032407   129.523148   159.532407   111.129630
# 2.33         70.532189    48.223176    60.484979    76.866953    45.403433
# 2.49         27.128514    15.710843    23.265060    30.570281    13.554217
# 2.66          8.067669     3.631579     7.187970     9.973684     1.582707
# 2.82          1.560284     0.117021     1.641844     2.769504    -1.755319
# 2.99         -0.210702    -0.752508     0.020067     0.705686    -2.317726
# 3.15         -0.644444    -0.980952    -0.431746     0.142857    -2.231746
# 3.32         -0.792169    -1.036145    -0.566265    -0.114458    -2.072289
# 3.48         -0.859195    -1.002874    -0.612069    -0.344828    -2.020115
# 3.65         -0.863014    -0.895890    -0.676712    -0.561644    -2.106849
# 3.81         -0.811024    -0.727034    -0.845144    -0.721785    -2.328084
# 3.97         -0.710327    -0.523929    -1.123426    -0.775819    -2.599496
# 4.14         -0.584541    -0.333333    -1.427536    -0.712560    -2.797101
# 4.30         -0.462791    -0.197674    -1.667442    -0.555814    -2.832558
# 4.47         -0.362416    -0.143177    -1.778523    -0.344519    -2.673378
# 4.63         -0.278618    -0.250540    -1.773218    -0.120950    -2.401728
# 4.80         -0.202083    -0.362500    -1.658333     0.077083    -2.097917
# 4.96         -0.076613    -0.469758    -1.443548     0.221774    -1.836694
# 5.13         -0.038986    -0.524366    -1.132554     0.288499    -1.627680
# 5.29         -0.034026    -0.497164    -0.784499     0.155009    -1.410208
# 5.46         -0.071429    -0.390110    -0.474359    -0.010989    -1.338828
# 5.62         -0.161922    -0.247331    -0.281139    -0.160142    -1.284698
# 5.78         -0.292388    -0.138408    -0.233564    -0.235294    -1.216263
# 5.95         -0.425210    -0.107563    -0.312605    -0.210084    -1.121008
# ...                ...          ...          ...          ...          ...
# 345.40        0.000000     0.000000    -0.103474     0.000000     0.000000
# 346.30        0.000000     0.000000    -0.102628     0.000000     0.000000
# 347.19        0.000000     0.000000    -0.098793     0.000000     0.000000
# 348.09        0.000000     0.000000    -0.092677     0.000000     0.000000
# 348.99        0.000000     0.000000    -0.085991     0.000000     0.000000
# 349.89        0.000000     0.000000    -0.080425     0.000000     0.000000
# 350.78        0.000000     0.000000     0.000000     0.000000     0.000000
# 351.68        0.000000     0.000000     0.000000     0.000000     0.000000
# 352.58        0.000000     0.000000     0.000000     0.000000     0.000000
# 353.48        0.000000     0.000000     0.000000     0.000000     0.000000
# 354.37        0.000000     0.000000     0.000000     0.000000     0.000000
# 355.27        0.000000     0.000000     0.000000     0.000000     0.000000
# 356.17        0.000000     0.000000     0.000000     0.000000     0.000000
# 357.07        0.000000     0.000000     0.000000     0.000000     0.000000
# 357.97        0.000000     0.000000     0.000000     0.000000     0.000000
# 358.86        0.000000     0.000000     0.000000     0.000000     0.000000
# 359.76        0.000000     0.000000     0.000000     0.000000     0.000000
# 360.66        0.000000     0.000000     0.000000     0.000000     0.000000
# 361.56        0.000000     0.000000     0.000000     0.000000     0.000000
# 362.45        0.000000     0.000000     0.000000     0.000000     0.000000
# 363.35        0.000000     0.000000     0.000000     0.000000     0.000000
# 364.25        0.000000     0.000000     0.000000     0.000000     0.000000
# 365.15        0.000000     0.000000     0.000000     0.000000     0.000000
# 366.04        0.000000     0.000000     0.000000     0.000000     0.000000
# 366.94        0.000000     0.000000     0.000000     0.000000     0.000000
# 367.84        0.000000     0.000000     0.000000     0.000000     0.000000
# 368.74        0.000000     0.000000     0.000000     0.000000     0.000000
# 369.63        0.000000     0.000000     0.000000     0.000000     0.000000
# 370.53        0.000000     0.000000     0.000000     0.000000     0.000000
# 371.43        0.000000     0.000000     0.000000     0.000000     0.000000
#
#                    H12
# Size (nt)
# 0.30       4167.766667
# 0.47       4324.893617
# 0.65       4175.215385
# 0.82       3638.463415
# 1.00       2707.210000
# 2.00       1017.435000
# 2.16        594.004630
# 2.33        304.506438
# 2.49        155.497992
# 2.66         92.259398
# 2.82         64.539007
# 2.99         45.254181
# 3.15         28.511111
# 3.32         15.403614
# 3.48          7.229885
# 3.65          3.180822
# 3.81          1.679790
# 3.97          1.329975
# 4.14          1.306763
# 4.30          1.262791
# 4.47          1.109620
# 4.63          0.913607
# 4.80          0.768750
# 4.96          0.743952
# 5.13          0.840156
# 5.29          1.007561
# 5.46          1.177656
# 5.62          1.306050
# 5.78          1.368512
# 5.95          1.364706
# ...                ...
# 345.40        0.010654
# 346.30        0.008345
# 347.19        0.006250
# 348.09        0.004826
# 348.99        0.004184
# 349.89        0.004173
# 350.78        0.004419
# 351.68        0.004578
# 352.58        0.004765
# 353.48        0.005234
# 354.37        0.006293
# 355.27        0.007712
# 356.17        0.008844
# 357.07        0.009102
# 357.97        0.008241
# 358.86        0.006632
# 359.76        0.004864
# 360.66        0.003327
# 361.56        0.002074
# 362.45        0.000773
# 363.35       -0.000881
# 364.25       -0.002938
# 365.15       -0.004929
# 366.04       -0.006256
# 366.94       -0.006459
# 367.84       -0.005519
# 368.74       -0.003797
# 369.63       -0.001759
# 370.53        0.000000
# 371.43        0.000000
#
# [567 rows x 96 columns]

# %%
for col in cols:
    for row in rows:
        df[col+row] = df[col+row]/df.index

# %%
df.loc[1:100, df.columns != "H12"].plot(legend = False)
df.loc[5:20, df.columns != "H12"].plot(legend = False)
df.loc[50:100, df.columns != "H12"].plot(legend = False)

# %% [raw]
# for col in cols:
#     plots = [col+x for x in rows]
#     if "H12" in plots:
#         plots.remove("H12")
#     df.loc[0:100, plots].plot(title=col)

# %%
df.loc[0:100, "H12"].plot(title="H12")

# %% [markdown]
# Looking for the controooools in this?

# %%
newDf = deepcopy(df)

def m(cell, cellTwo):
    return cell+"-"+cellTwo

for col in cols:
    oldCell = ""
    for row in rows:
        cell = col+row
        if cell == "H12":
            break
        if oldCell == "":
            newDf["All Mult."] = newDf[cell]
        else:
            newDf["All Mult."] = newDf[cell]+newDf["All Mult."]
        oldCell = "adsflh"
newDf.loc[0:100, "All Mult."].plot()

# %%
newDf = deepcopy(df)

#do curve-fitting later
#poly = PolynomialFeatures(degree = 4) 
#poly_func = poly.fit_transform(X) 
#poly.fit(poly_func, y)

peakLocations = {}
peaks = {"secondPeak":[8,11.5,0.2], "lastPeak":[60,90,0.0001]}
for col in cols:
    for row in rows:
        varArr = []
        for peak in peaks:
            if not (col == "H" and row == "12"):
                foundPeaks = scipy.signal.find_peaks(list(newDf.loc[peaks[peak][0]:peaks[peak][1], col+row]), height=peaks[peak][2])
                if len(foundPeaks[0])==0:
                    print("Found no", peak, "peaks for",col+row)
                if len(foundPeaks[0]) == 1:
                    #print("Found one ", peak," peak for ", col+row)
                    peakloc = foundPeaks[0][0]
                    varArr.extend([peakloc])
                else:
                    display(foundPeaks)
                    print("Found multiple ", peak," peaks for ", col+row)
                    numpeaks = len(foundPeaks[0])
                    display(numpeaks)
                    #peakloc = foundPeaks[numpeaks-1][0]
                    varArr.extend([0])
        peakLocations[col+row] = varArr
            
display(peakLocations)
# Out:
# (array([ 6, 21], dtype=int64),
#  {'peak_heights': array([0.00184179, 0.0093345 ])})
# Found multiple  lastPeak  peaks for  A1
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00221134, 0.0106319 ])})
# Found multiple  lastPeak  peaks for  A2
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00216976, 0.01044144])})
# Found multiple  lastPeak  peaks for  A3
# 2
# (array([ 4, 20], dtype=int64),
#  {'peak_heights': array([0.00218019, 0.01079254])})
# Found multiple  lastPeak  peaks for  A4
# 2
# (array([ 1, 16], dtype=int64),
#  {'peak_heights': array([0.00261102, 0.01264246])})
# Found multiple  lastPeak  peaks for  A6
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00239724, 0.01128587])})
# Found multiple  lastPeak  peaks for  A8
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00223008, 0.01059154])})
# Found multiple  lastPeak  peaks for  B1
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00229673, 0.0099547 ])})
# Found multiple  lastPeak  peaks for  B2
# 2
# (array([ 6, 21], dtype=int64),
#  {'peak_heights': array([0.00220813, 0.0104045 ])})
# Found multiple  lastPeak  peaks for  B5
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00249858, 0.0110637 ])})
# Found multiple  lastPeak  peaks for  B8
# 2
# (array([ 2, 17], dtype=int64),
#  {'peak_heights': array([0.00253259, 0.01157565])})
# Found multiple  lastPeak  peaks for  B9
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00261332, 0.01206048])})
# Found multiple  lastPeak  peaks for  B11
# 2
# (array([ 4, 19], dtype=int64),
#  {'peak_heights': array([0.00204485, 0.00994121])})
# Found multiple  lastPeak  peaks for  B12
# 2
# (array([ 8, 24], dtype=int64),
#  {'peak_heights': array([0.00195859, 0.00905609])})
# Found multiple  lastPeak  peaks for  C1
# 2
# (array([ 5, 20], dtype=int64),
#  {'peak_heights': array([0.00192567, 0.00938882])})
# Found multiple  lastPeak  peaks for  C2
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00226597, 0.01049904])})
# Found multiple  lastPeak  peaks for  C3
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00267488, 0.01239232])})
# Found multiple  lastPeak  peaks for  C4
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00201545, 0.00927334])})
# Found multiple  lastPeak  peaks for  C6
# 2
# (array([ 4, 20], dtype=int64),
#  {'peak_heights': array([0.00228784, 0.01072286])})
# Found multiple  lastPeak  peaks for  C7
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00235526, 0.01082311])})
# Found multiple  lastPeak  peaks for  C8
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00232455, 0.01083478])})
# Found multiple  lastPeak  peaks for  C9
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.0026104 , 0.01184291])})
# Found multiple  lastPeak  peaks for  C12
# 2
# (array([ 1, 16], dtype=int64),
#  {'peak_heights': array([0.00265021, 0.0120206 ])})
# Found multiple  lastPeak  peaks for  D1
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00230337, 0.01027321])})
# Found multiple  lastPeak  peaks for  D4
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00155494, 0.00692131])})
# Found multiple  lastPeak  peaks for  D5
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00209662, 0.00942757])})
# Found multiple  lastPeak  peaks for  D6
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00210259, 0.00936545])})
# Found multiple  lastPeak  peaks for  D7
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00237499, 0.01033022])})
# Found multiple  lastPeak  peaks for  D8
# 2
# (array([ 5, 20], dtype=int64),
#  {'peak_heights': array([0.00210726, 0.00939631])})
# Found multiple  lastPeak  peaks for  D11
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.0022759 , 0.01006573])})
# Found multiple  lastPeak  peaks for  E1
# 2
# (array([ 5, 20], dtype=int64),
#  {'peak_heights': array([0.00200345, 0.00911356])})
# Found multiple  lastPeak  peaks for  E3
# 2
# (array([ 3, 18], dtype=int64),
#  {'peak_heights': array([0.00221059, 0.00993904])})
# Found multiple  lastPeak  peaks for  E4
# 2
# (array([ 3, 18], dtype=int64),
#  {'peak_heights': array([0.00212948, 0.00967912])})
# Found multiple  lastPeak  peaks for  E6
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00247509, 0.01061424])})
# Found multiple  lastPeak  peaks for  E8
# 2
# (array([ 4, 19], dtype=int64),
#  {'peak_heights': array([0.00219043, 0.00968757])})
# Found multiple  lastPeak  peaks for  E10
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.0024404 , 0.01018352])})
# Found multiple  lastPeak  peaks for  E11
# 2
# (array([ 4, 19], dtype=int64),
#  {'peak_heights': array([0.00235836, 0.01054682])})
# Found multiple  lastPeak  peaks for  E12
# 2
# (array([ 3, 18], dtype=int64),
#  {'peak_heights': array([0.00263301, 0.01191412])})
# Found multiple  lastPeak  peaks for  F5
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00225723, 0.0099035 ])})
# Found multiple  lastPeak  peaks for  F7
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00280327, 0.01175192])})
# Found multiple  lastPeak  peaks for  F9
# 2
# (array([ 2, 16], dtype=int64),
#  {'peak_heights': array([0.00267741, 0.0121254 ])})
# Found multiple  lastPeak  peaks for  G1
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00272402, 0.01215759])})
# Found multiple  lastPeak  peaks for  G2
# 2
# (array([ 4, 20], dtype=int64),
#  {'peak_heights': array([0.00245501, 0.01099834])})
# Found multiple  lastPeak  peaks for  G3
# 2
# (array([ 6, 22], dtype=int64),
#  {'peak_heights': array([0.00231882, 0.01043091])})
# Found multiple  lastPeak  peaks for  G4
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00284665, 0.01274735])})
# Found multiple  lastPeak  peaks for  G5
# 2
# (array([ 4, 20], dtype=int64),
#  {'peak_heights': array([0.00263852, 0.01207455])})
# Found multiple  lastPeak  peaks for  G6
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.0029963 , 0.01315509])})
# Found multiple  lastPeak  peaks for  G7
# 2
# (array([ 1, 16], dtype=int64),
#  {'peak_heights': array([0.00311799, 0.01387992])})
# Found multiple  lastPeak  peaks for  G8
# 2
# (array([ 5, 31], dtype=int64),
#  {'peak_heights': array([0.02200706, 0.00010853])})
# Found multiple  lastPeak  peaks for  G9
# 2
# (array([ 6, 21], dtype=int64),
#  {'peak_heights': array([0.00275955, 0.0128529 ])})
# Found multiple  lastPeak  peaks for  H1
# 2
# (array([ 1, 16], dtype=int64),
#  {'peak_heights': array([0.00319621, 0.01424891])})
# Found multiple  lastPeak  peaks for  H3
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00340837, 0.01509909])})
# Found multiple  lastPeak  peaks for  H5
# 2
# (array([ 2, 18], dtype=int64),
#  {'peak_heights': array([0.00287151, 0.01301643])})
# Found multiple  lastPeak  peaks for  H6
# 2
# (array([ 4, 20], dtype=int64),
#  {'peak_heights': array([0.00286186, 0.01258389])})
# Found multiple  lastPeak  peaks for  H7
# 2
# (array([ 3, 20], dtype=int64),
#  {'peak_heights': array([0.00347983, 0.01411457])})
# Found multiple  lastPeak  peaks for  H8
# 2
# (array([ 5, 21], dtype=int64),
#  {'peak_heights': array([0.00293396, 0.01145657])})
# Found multiple  lastPeak  peaks for  H9
# 2
# (array([ 3, 19], dtype=int64),
#  {'peak_heights': array([0.00401316, 0.01405387])})
# Found multiple  lastPeak  peaks for  H10
# 2
# (array([ 1, 17], dtype=int64),
#  {'peak_heights': array([0.00383789, 0.01388207])})
# Found multiple  lastPeak  peaks for  H11
# 2
# {'A1': [18, 0],
#  'A2': [15, 0],
#  'A3': [16, 0],
#  'A4': [16, 0],
#  'A5': [15, 14],
#  'A6': [16, 0],
#  'A7': [15, 14],
#  'A8': [16, 0],
#  'A9': [15, 13],
#  'A10': [14, 15],
#  'A11': [14, 14],
#  'A12': [14, 14],
#  'B1': [16, 0],
#  'B2': [16, 0],
#  'B3': [12, 6],
#  'B4': [12, 11],
#  'B5': [18, 0],
#  'B6': [13, 13],
#  'B7': [14, 13],
#  'B8': [15, 0],
#  'B9': [16, 0],
#  'B10': [14, 13],
#  'B11': [16, 0],
#  'B12': [15, 0],
#  'C1': [18, 0],
#  'C2': [17, 0],
#  'C3': [17, 0],
#  'C4': [16, 0],
#  'C5': [15, 15],
#  'C6': [16, 0],
#  'C7': [16, 0],
#  'C8': [16, 0],
#  'C9': [16, 0],
#  'C10': [15, 16],
#  'C11': [15, 16],
#  'C12': [15, 0],
#  'D1': [15, 0],
#  'D2': [15, 15],
#  'D3': [15, 15],
#  'D4': [15, 0],
#  'D5': [15, 0],
#  'D6': [17, 0],
#  'D7': [16, 0],
#  'D8': [16, 0],
#  'D9': [14, 11],
#  'D10': [15, 16],
#  'D11': [16, 0],
#  'D12': [14, 14],
#  'E1': [16, 0],
#  'E2': [14, 10],
#  'E3': [17, 0],
#  'E4': [16, 0],
#  'E5': [14, 14],
#  'E6': [16, 0],
#  'E7': [16, 16],
#  'E8': [16, 0],
#  'E9': [15, 14],
#  'E10': [16, 0],
#  'E11': [16, 0],
#  'E12': [17, 0],
#  'F1': [15, 15],
#  'F2': [15, 13],
#  'F3': [12, 6],
#  'F4': [11, 3],
#  'F5': [16, 0],
#  'F6': [14, 13],
#  'F7': [16, 0],
#  'F8': [14, 16],
#  'F9': [17, 0],
#  'F10': [13, 9],
#  'F11': [13, 7],
#  'F12': [14, 11],
#  'G1': [16, 0],
#  'G2': [17, 0],
#  'G3': [17, 0],
#  'G4': [18, 0],
#  'G5': [17, 0],
#  'G6': [17, 0],
#  'G7': [16, 0],
#  'G8': [16, 0],
#  'G9': [12, 0],
#  'G10': [13, 11],
#  'G11': [12, 4],
#  'G12': [11, 6],
#  'H1': [17, 0],
#  'H2': [13, 12],
#  'H3': [15, 0],
#  'H4': [12, 10],
#  'H5': [15, 0],
#  'H6': [16, 0],
#  'H7': [17, 0],
#  'H8': [16, 0],
#  'H9': [18, 0],
#  'H10': [17, 0],
#  'H11': [15, 0],
#  'H12': []}

# %%
modvals = vals.replace("Cont", np.nan).astype(float)
corr = modvals.corr()
display(corr)
display(sns.heatmap(corr))
# Out:
#                               Nuc.      time (s)  injectPeak: Location  \
# Nuc.                  1.000000e+00 -2.576001e-17             -0.184001
# time (s)             -2.576001e-17  1.000000e+00             -0.068854
# injectPeak: Location -1.840012e-01 -6.885409e-02              1.000000
# injectPeak: Height    6.786989e-01  3.386052e-02             -0.254570
# secondPeak: Location  1.253107e-01  3.785692e-01             -0.228602
# secondPeak: Height   -1.598602e-01 -6.719466e-01             -0.013821
# lastPeak: Location   -1.192581e-02 -1.724665e-01             -0.249221
# lastPeak: Height      5.673724e-01  1.423817e-01              0.015470
#
#                       injectPeak: Height  secondPeak: Location  \
# Nuc.                            0.678699              0.125311
# time (s)                        0.033861              0.378569
# injectPeak: Location           -0.254570             -0.228602
# injectPeak: Height              1.000000              0.345350
# secondPeak: Location            0.345350              1.000000
# secondPeak: Height             -0.079750             -0.395550
# lastPeak: Location              0.330590              0.653330
# lastPeak: Height                0.748138             -0.134221
#
#                       secondPeak: Height  lastPeak: Location  lastPeak: Height
# Nuc.                           -0.159860           -0.011926          0.567372
# time (s)                       -0.671947           -0.172466          0.142382
# injectPeak: Location           -0.013821           -0.249221          0.015470
# injectPeak: Height             -0.079750            0.330590          0.748138
# secondPeak: Location           -0.395550            0.653330         -0.134221
# secondPeak: Height              1.000000            0.203159         -0.015298
# lastPeak: Location              0.203159            1.000000         -0.415622
# lastPeak: Height               -0.015298           -0.415622          1.000000

# %% [raw]
# fig, ax = plt.subplots()
# ax.scatter(modvals["Nuc."],modvals["Peak Height"])

# %%
df.loc[11.5:14, df.columns != "H12"].plot(legend = False)

# %%
df.loc[7:14, df.columns != "H12"].plot(legend = False)

# %%
df.loc[11.5:14, "D12"].plot(title="A12")
